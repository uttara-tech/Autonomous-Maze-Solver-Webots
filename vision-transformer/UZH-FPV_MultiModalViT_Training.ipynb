# %% [markdown]
# <font color='green'> <br>
#     ***********************************************************************************************  <br><br>
#     &emsp; Deep Learning Project:&emsp; drone-vision-transformer <br><br>
#     &emsp; Author:&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp; Uttara Naidu <br><br>
#     &emsp; Date:&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 16/04/2026 <br><br>
#     &emsp; Version: &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;v0.2 (WIP) <br><br>
#     &emsp; Description:&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; Creates a ViT+RL model for inference in drone controller <br><br>
#     ***********************************************************************************************  <br>
#  </font>
#
# <font color='blue'> NOTE: This is a work-in-progress. Code clean-up, documentation and further updates will follow soon. </font>

# %% [markdown]
# The dataset is downloaded from: https://fpv.ifi.uzh.ch/datasets/
#
# *Indoor forward facing:*
#
# Rogbag file: indoor_forward_5_snapdragon_with_gt.bag

# %%
from rosbags.highlevel import AnyReader
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

import sys, warnings

bag_path = Path('/Users/uni/data_files/fpv/indoor_forward_5_snapdragon_with_gt.bag')                # Path to downloaded .bag file
PROJ_DIR = '/Users/uni/dl_project_workspace/drone-vision-transformer'
DATA_DIR =  f'{PROJ_DIR}/data'
sys.path.append('/Users/uni/dl_project_workspace/drone-vision-transformer/')

from scripts.data_loader import explore_data, extract_data
from scripts.data_preprocessing import ViTDataset
from scripts.multimodal_vit import MultiModalViT

explore_data(bag_path)
# Out:
# TOPIC                          | MSG TYPE                       | COUNT
# ---------------------------------------------------------------------------
# /groundtruth/odometry          | nav_msgs/msg/Odometry          | 9650
# /groundtruth/pose              | geometry_msgs/msg/PoseStamped  | 9650
# /snappy_cam/stereo_l           | sensor_msgs/msg/Image          | 4162
# /snappy_cam/stereo_r           | sensor_msgs/msg/Image          | 4162
# /snappy_imu                    | sensor_msgs/msg/Imu            | 75042

# %%
data_dir = Path(f"{DATA_DIR}/images")
data_dir.mkdir(parents=True, exist_ok=True)

extract_data(bag_path,data_dir)
# Out:
# ----------- NUMBER OF DATA POINTS -----------
# Images:8324 | IMU:75042 | Odometry:9650 | Pose:9650
# Dataset created with 8324 synchronized rows.
# Saved 75042 IMU messages to imu_data.csv

# %%
import pandas as pd

data = pd.read_csv(f'{DATA_DIR}/drone_dataset.csv')
data.head()
# Out:
#              timestamp  cam_id  \
# 0  1540821095628558395       0
# 1  1540821095628558395       1
# 2  1540821095661733604       0
# 3  1540821095661733604       1
# 4  1540821095694906448       0
#
#                                             img_path  imu_start_ts  \
# 0  /Users/uni/dl_project_workspace/drone-vision-t...  1.540821e+18
# 1  /Users/uni/dl_project_workspace/drone-vision-t...  1.540821e+18
# 2  /Users/uni/dl_project_workspace/drone-vision-t...  1.540821e+18
# 3  /Users/uni/dl_project_workspace/drone-vision-t...  1.540821e+18
# 4  /Users/uni/dl_project_workspace/drone-vision-t...  1.540821e+18
#
#      imu_end_ts     pos_x     pos_y     pos_z     ori_w  vel_x  vel_y  vel_z
# 0  1.540821e+18  7.481608 -0.005923 -0.907926 -0.455032    0.0    0.0    0.0
# 1  1.540821e+18  7.481608 -0.005923 -0.907926 -0.455032    0.0    0.0    0.0
# 2  1.540821e+18  7.481608 -0.005923 -0.907926 -0.455032    0.0    0.0    0.0
# 3  1.540821e+18  7.481608 -0.005923 -0.907926 -0.455032    0.0    0.0    0.0
# 4  1.540821e+18  7.481608 -0.005923 -0.907926 -0.455032    0.0    0.0    0.0

# %%
data.plot(x='timestamp',y=['pos_x','pos_y','pos_z','ori_w'],figsize=(10,6))
plt.ticklabel_format(useOffset=False, style='plain', axis='x')
plt.gcf().autofmt_xdate()

# %%
imu_df = pd.read_csv(f'{DATA_DIR}/imu_data.csv')
imu_df.head()
# Out:
#              timestamp     acc_x     acc_y     acc_z    gyro_x    gyro_y  \
# 0  1540821095597876000 -0.124498 -0.220265  9.691679 -0.009587 -0.003196
# 1  1540821095599871000 -0.110133 -0.220265  9.706043 -0.006392 -0.004261
# 2  1540821095601871000 -0.124498 -0.186747  9.677314 -0.006392 -0.002131
# 3  1540821095603869000 -0.110133 -0.225054  9.725197 -0.004261  0.001065
# 4  1540821095605868000 -0.105344 -0.205900  9.753927 -0.001065 -0.003196
#
#      gyro_z
# 0 -0.001065
# 1 -0.002131
# 2 -0.005326
# 3 -0.003196
# 4 -0.002131

# %%
imu_df.plot(x='timestamp',figsize=(10,6))
plt.ticklabel_format(useOffset=False, style='plain', axis='x')
plt.gcf().autofmt_xdate()

# %%
from PIL import Image
import matplotlib.pyplot as plt
import random

fig, ax = plt.subplots(3,5,figsize=(10,10))
axes_flat = ax.flatten()

random_idx = [random.randint(1,8000) for _ in range(15)]

for ax,idx in zip(axes_flat,random_idx):
    img = Image.open(data['img_path'][idx])
    ax.imshow(img)
    ax.set_title(f'\nSize:{img.size}, \nChannels:{img.getbands()}')
    ax.axis('off')

plt.tight_layout() 
plt.show()

# %%
import torch

# iMac-specific setup
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
dataset = ViTDataset(f'{DATA_DIR}/drone_dataset.csv',f'{DATA_DIR}/imu_data.csv',DATA_DIR)

# %%
from torch.utils.data import DataLoader

dataloader = DataLoader(dataset,batch_size=1,shuffle=True)
images, imu_sample,pos = next(iter(dataloader))
print('[INFO] Input tensor shape [B,C,H,W]: ',images.shape)
print('\n[INFO] IMU Window Statistics [Mean]: ')
print(f'\n Acceleration (x,y,z): ({imu_sample.tolist()[0][0]},{imu_sample.tolist()[0][1]},{imu_sample.tolist()[0][2]})')
print(f'\n Gyro (x,y,z): ({imu_sample.tolist()[0][3]},{imu_sample.tolist()[0][4]},{imu_sample.tolist()[0][5]})')
print(f'\n[INFO] Target pose (x,y,z):, {pos.tolist()}')
# Out:
# [INFO] Input tensor shape [B,C,H,W]:  torch.Size([1, 1, 256, 256])
#
# [INFO] IMU Window Statistics [Mean]:
#
#  Acceleration (x,y,z): (-0.2859620153903961,-0.06521772593259811,8.420746803283691)
#
#  Gyro (x,y,z): (-0.09642773866653442,-0.04471980407834053,0.49847984313964844)
#
# [INFO] Target pose (x,y,z):, [[7.065465450286865, -2.9854683876037598, 0.09221266955137253]]

# %%
from torchinfo import summary

model = MultiModalViT(img_size=(256,256))
summary(model, [(1, 1, 256, 256),(1, 16, 6) ])
# Out:
# [INFO] Input tensor shape [B,C,H,W]:  torch.Size([1, 1, 256, 256])
# [INFO] Extracting patches ...
# [INFO] Number of patches:  256
# [INFO] Number of heads:  8
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MultiModalViT                            [1, 112]                  70,144
# ├─MultiModalEmbed: 1-1                   [1, 272, 256]             4,096
# │    └─PatchEmbed: 2-1                   [1, 256, 256]             --
# │    │    └─Linear: 3-1                  [1, 256, 256]             65,792
# │    └─Linear: 2-2                       [1, 16, 256]              1,792
# ├─ModuleList: 1-2                        --                        --
# │    └─TransformerEncoderBlock: 2-3      [1, 273, 256]             --
# │    │    └─MultiHeadAttention: 3-2      [1, 273, 256]             263,168
# │    │    └─Dropout: 3-3                 [1, 273, 256]             --
# │    │    └─LayerNorm: 3-4               [1, 273, 256]             512
# │    │    └─Sequential: 3-5              [1, 273, 256]             262,912
# │    │    └─Dropout: 3-6                 [1, 273, 256]             --
# │    │    └─LayerNorm: 3-7               [1, 273, 256]             512
# │    └─TransformerEncoderBlock: 2-4      [1, 273, 256]             --
# │    │    └─MultiHeadAttention: 3-8      [1, 273, 256]             263,168
# │    │    └─Dropout: 3-9                 [1, 273, 256]             --
# │    │    └─LayerNorm: 3-10              [1, 273, 256]             512
# │    │    └─Sequential: 3-11             [1, 273, 256]             262,912
# │    │    └─Dropout: 3-12                [1, 273, 256]             --
# │    │    └─LayerNorm: 3-13              [1, 273, 256]             512
# │    └─TransformerEncoderBlock: 2-5      [1, 273, 256]             --
# │    │    └─MultiHeadAttention: 3-14     [1, 273, 256]             263,168
# │    │    └─Dropout: 3-15                [1, 273, 256]             --
# │    │    └─LayerNorm: 3-16              [1, 273, 256]             512
# │    │    └─Sequential: 3-17             [1, 273, 256]             262,912
# │    │    └─Dropout: 3-18                [1, 273, 256]             --
# │    │    └─LayerNorm: 3-19              [1, 273, 256]             512
# │    └─TransformerEncoderBlock: 2-6      [1, 273, 256]             --
# │    │    └─MultiHeadAttention: 3-20     [1, 273, 256]             263,168
# │    │    └─Dropout: 3-21                [1, 273, 256]             --
# │    │    └─LayerNorm: 3-22              [1, 273, 256]             512
# │    │    └─Sequential: 3-23             [1, 273, 256]             262,912
# │    │    └─Dropout: 3-24                [1, 273, 256]             --
# │    │    └─LayerNorm: 3-25              [1, 273, 256]             512
# │    └─TransformerEncoderBlock: 2-7      [1, 273, 256]             --
# │    │    └─MultiHeadAttention: 3-26     [1, 273, 256]             263,168
# │    │    └─Dropout: 3-27                [1, 273, 256]             --
# │    │    └─LayerNorm: 3-28              [1, 273, 256]             512
# │    │    └─Sequential: 3-29             [1, 273, 256]             262,912
# │    │    └─Dropout: 3-30                [1, 273, 256]             --
# │    │    └─LayerNorm: 3-31              [1, 273, 256]             512
# │    └─TransformerEncoderBlock: 2-8      [1, 273, 256]             --
# │    │    └─MultiHeadAttention: 3-32     [1, 273, 256]             263,168
# │    │    └─Dropout: 3-33                [1, 273, 256]             --
# │    │    └─LayerNorm: 3-34              [1, 273, 256]             512
# │    │    └─Sequential: 3-35             [1, 273, 256]             262,912
# │    │    └─Dropout: 3-36                [1, 273, 256]             --
# │    │    └─LayerNorm: 3-37              [1, 273, 256]             512
# ├─LayerNorm: 1-3                         [1, 273, 256]             512
# ├─Linear: 1-4                            [1, 112]                  28,784
# ==========================================================================================
# Total params: 3,333,744
# Trainable params: 3,333,744
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 3.26
# ==========================================================================================
# Input size (MB): 0.26
# Forward/backward pass size (MB): 31.31
# Params size (MB): 13.04
# Estimated Total Size (MB): 44.61
# ==========================================================================================
